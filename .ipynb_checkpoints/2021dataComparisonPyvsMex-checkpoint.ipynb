# %%
import pandas as pd
import pytz, datetime
import pytz
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
path='DatosMexico/2020/Marzo/'
datos= pd.read_csv(path+"DAT02-31_Marzo.csv", dtype={'Fecha': 'str','Hora(UTC)': 'str'})
mex=pd.DataFrame(datos)
mex['datetime']=pd.to_datetime(mex['Fecha'] +mex['Hora(UTC)'], format='%d%m%y%H%M%S')
mex.set_index(['datetime'],drop=True, inplace=True)

# %%
mex.head()
flag=np.logical_and(mex.index>"2020-03-01",mex.index<"2020-03-03")

# %%
path='DatosMexico/2020/Marzo/'
filenamePy=path+'muonFlux.json'

# %%
counts = pd.read_json (filenamePy, lines=True)
counts['datetime']=pd.to_datetime(counts.hora, unit='s',utc=True)

counts.set_index(['datetime'],drop=True, inplace=True)
counts= counts.iloc[1:]

# %%
fig, axes = plt.subplots(2,1, figsize=(15,5), sharex=True)
plt.subplot(211)

axes =counts['conteo'].plot(marker='.',markersize=2.5, ylim=(300,500),linestyle='None',legend=True,  label='Paraguay Febrero 2021 (15 al 16)',alpha=1,color='r', subplots=True)
ax = plt.gca()
ax.set_ylabel('Counts')
plt.subplot(212)
axes =df['Coincidencias'][flag].plot(marker='.',markersize=2.5, ylim=(30,140),linestyle='None',legend=True,  label='México Marzo 2020 (2 al 6)',alpha=1,color='b', subplots=True)
ax = plt.gca()
ax.set_ylabel('Counts')
ax.set_xlabel('Date')
plt.xticks(rotation = 45)
plt.savefig('EscaramujovsParaguay.png')

# %%
fig, axes = plt.subplots(1,2, figsize=(10,5), sharex=True)
plt.subplot(121)
sns.set(style="whitegrid")
ax = sns.boxplot(data=df['Coincidencias'].values)
plt.subplot(122)
sns.set(style="whitegrid")
ax = sns.boxplot(data=counts['conteo'].values)
plt.savefig("boxplot.png", bbox_inches='tight')

# %%
#counts.to_csv('py.csv')
