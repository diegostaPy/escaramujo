# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
data= pd.read_csv("dscovr/rtsw_plot_data_2021-04-09T00 00 00.txt",skiprows=12,sep='\s+')

# %%
data.head(10)
# Out:
#            Timestamp  Source  Bt-med  Bt-min  Bt-max  Bx-med  Bx-min  Bx-max  \
# 2021-04-09  00:00:00       1    4.71    4.36    4.88   -4.11   -4.39   -3.51
# 2021-04-09  00:30:00       1    4.54    4.15    4.71   -4.15   -4.40   -3.75
# 2021-04-09  01:00:00       1    4.04    3.86    4.28   -3.24   -3.82   -3.03
# 2021-04-09  01:30:00       1    4.35    3.80    4.51   -3.70   -4.05   -2.48
# 2021-04-09  02:00:00       1    3.84    3.52    4.27   -1.84   -2.53   -0.71
# 2021-04-09  02:30:00       1    3.94    3.58    4.21   -1.57   -2.18   -0.46
# 2021-04-09  03:00:00       1    3.08    1.93    4.10   -1.56   -2.45    0.12
# 2021-04-09  03:30:00       1    2.92    1.94    3.02    1.78   -0.53    2.18
# 2021-04-09  04:00:00       1    2.90    2.46    3.12    1.31   -0.08    1.93
# 2021-04-09  04:30:00       1    2.89    2.21    3.57    0.36   -0.64    1.25
#
#             By-med  By-min  ...  Theta-max  Dens-med  Dens-min  Dens-max  \
# ...

# %%
data.columns
# Out:
# Index(['Timestamp', 'Source', 'Bt-med', 'Bt-min', 'Bt-max', 'Bx-med', 'Bx-min',
#        'Bx-max', 'By-med', 'By-min', 'By-max', 'Bz-med', 'Bz-min', 'Bz-max',
#        'Phi-mean', 'Phi-min', 'Phi-max', 'Theta-med', 'Theta-min', 'Theta-max',
#        'Dens-med', 'Dens-min', 'Dens-max', 'Speed-med', 'Speed-min',
#        'Speed-max', 'Temp-med', 'Temp-min', 'Temp-max'],
#       dtype='object')

# %%
data['date']=data.index.values
data['datetime']=pd.to_datetime(data.date+" "+data.Timestamp, format='%Y-%m-%d %H:%M:%S',utc=True)
data.set_index(['datetime'],drop=True, inplace=True)

# %%
#flag=np.logical_and(data.index>"2021-05-5",data.index<"2021-05-6")

# %%
data.head()
# Out:
#                           Timestamp  Source  Bt-med  Bt-min  Bt-max  Bx-med  \
# datetime
# 2021-04-09 00:00:00+00:00  00:00:00       1    4.71    4.36    4.88   -4.11
# 2021-04-09 00:30:00+00:00  00:30:00       1    4.54    4.15    4.71   -4.15
# 2021-04-09 01:00:00+00:00  01:00:00       1    4.04    3.86    4.28   -3.24
# 2021-04-09 01:30:00+00:00  01:30:00       1    4.35    3.80    4.51   -3.70
# 2021-04-09 02:00:00+00:00  02:00:00       1    3.84    3.52    4.27   -1.84
#
#                            Bx-min  Bx-max  By-med  By-min  ...  Dens-med  \
# datetime                                                   ...
# 2021-04-09 00:00:00+00:00   -4.39   -3.51   -0.82   -1.80  ...      4.53
# 2021-04-09 00:30:00+00:00   -4.40   -3.75   -1.16   -1.80  ...      4.82
# 2021-04-09 01:00:00+00:00   -3.82   -3.03    0.71   -1.30  ...      4.85
# 2021-04-09 01:30:00+00:00   -4.05   -2.48   -0.25   -0.72  ...      4.53
# ...

# %%
fig, axes = plt.subplots(3,1, figsize=(20,10), sharex=True)
plt.subplot(311)
axes =data['Bt-med'].astype(float).plot(marker='.',markersize=2.5,ylim=(1,5),linestyle='None',legend=True,alpha=1,color='black', subplots=True)
ax = plt.gca()
plt.subplot(312)
axes =data['Bx-med'].astype(float).plot(marker='.',markersize=2.5,ylim=(-5,5),linestyle='None',legend=True,alpha=1,color='red', subplots=True)
ax = plt.gca()
plt.subplot(313)
axes =data['Phi-mean'].astype(float).plot(marker='.',markersize=2.5,ylim=(0,360),linestyle='None',legend=False,alpha=1,color='blue', subplots=True)
ax = plt.gca()
